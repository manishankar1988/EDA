# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
data = sns.load_dataset('iris')

# %%
# Display the first few rows of the dataset
print(data.head())
# Basic info about the dataset
data.info()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Summary statistics
print(data.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Drop rows with missing values
data = data.dropna()

# Fill missing values with the mean of each column

# %% [markdown]
# To visualize the distribution of each numerical feature in the dataset.
# Helps to identify skewness, outliers, or trends in data.

# %%
# Histogram for each numerical column
data.hist(bins=8, figsize=(10, 10), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %% [markdown]
# This function generates histograms for all numerical columns in the data DataFrame.
# bins=20: Divides the range of each numerical feature into 20 bins (intervals).
# figsize=(10, 8): Sets the figure size to 10 inches (width) by 8 inches (height).
# color='skyblue': Fills the bars with a light blue color.
# edgecolor='black': Adds a black border around each bar for better visibility.
#
# Useful for data preprocessing ( deciding whether normalization or transformation is needed).

# %%
# Boxplot to visualize distributions
sns.boxplot(data=data)
plt.title("Boxplot of Iris Features")
plt.show()

# %% [markdown]
# Whisker length =1.5 X IQR
#
# Observations from the Boxplot:
# Sepal Length:
#
# The median (central line inside the box) is around 5.8 - 6.0 cm.
# The data is symmetrically distributed with no visible extreme outliers.
# The range is 4.3 cm to 7.9 cm.
# Sepal Width:
#
# The median is close to 3.0 cm.
# There are outliers below 2.0 cm and above 4.0 cm.
# The IQR is 2.7 cm to 3.4 cm, indicating a relatively small spread.
# Petal Length:
#
# The median is around 4.5 cm.
# This feature has the widest range, extending from 1 cm to around 7 cm.
# There is some skewness toward higher values.
# Petal Width:
#
# The median is approximately 1.3 cm.
# The distribution is fairly symmetric.
# No significant outliers are present.

# %% [markdown]
#  Outliers in Sepal Width: Some data points fall outside the whiskers, indicating variability in this feature.
#
#  Petal Length has the largest variability: The widest spread suggests that this feature is the most distinguishing among Iris species.
#
# Petal Width & Sepal Length are symmetrically distributed, indicating a balanced dataset.

# %%
# Distribution plot for Sepal Length
sns.displot(data['sepal_length'], kde=True, color='purple')
plt.title("Distribution Plot: Sepal Length")
plt.show()

# %% [markdown]
# sns.displot(data['sepal_length'], kde=True, color='purple')
#
# sns.displot(): Creates a distribution plot (histogram by default).
# data['sepal_length']: Uses the sepal length column from the dataset.
# kde=True: Adds a Kernel Density Estimation (KDE) curve, which smoothens the distribution.
# color='purple': Sets the plot color to purple.
# plt.title("Distribution Plot: Sepal Length")
#
# Adds a title to the plot.
# plt.show()
#
# Displays the plot.

# %% [markdown]
# The given histogram and KDE curve provide insights into the distribution of sepal length in the dataset.
#
# 1. Shape of Distribution
# The distribution appears to be slightly right-skewed, meaning that a few data points have larger sepal lengths.
# The highest frequency (peak) is around 5.5 - 6.0 cm, indicating that most samples have sepal lengths in this range.
# 2. Spread & Variability
# The values range approximately from 4.3 cm to 7.9 cm.
# The spread is moderate, meaning that there is some variation in sepal length across the dataset.
# 3. Presence of Multiple Peaks
# There might be two peaks (bimodal tendency), suggesting that different species in the dataset have different sepal length distributions.
# 4. KDE Curve Insights
# The Kernel Density Estimation (KDE) curve smooths the histogram and shows that most values are concentrated between 5.0 cm and 6.5 cm.
# The decline in frequency towards higher sepal lengths (7.0 cm and above) suggests that fewer flowers have such large sepals.
# 5. Possible Outliers
# Some low-count bins around 4.3 cm and 7.9 cm might indicate outliers or rare occurrences.

# %%
# Bar plot to see species counts
sns.countplot(x='species', data=data)
plt.title("Bar Plot: Species Count")
plt.show()

# %% [markdown]
# s.countplot(x='species', data=data)
#
# Creates a bar plot where the x-axis represents different species categories.
# The y-axis represents the count (frequency) of each species in the dataset.
# x='species' → Specifies that the species column should be plotted on the x-axis.
# data=data → Uses the dataset stored in the data variable.
# plt.title("Bar Plot: Species Count")
#
# Adds a title to the plot for clarity.
# plt.show()
#
# Displays the plot. in Matplotlib
# "viridis" (default perceptually uniform colormap)
# "plasma"
# "inferno"
# "magma"
# "coolwarm"
# "Blues", "Reds", "Greens" (monochromatic schemes)

# %%
sns.countplot(x='species', data=data, palette="viridis")
# Out:
# <ipython-input-12-74a22d8b7524>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=data, palette="viridis")
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# Seaborn provides several predefined color palettes that you can use:
#
# "deep" (default) – Distinct, visually appealing colors.
# "muted" – Softer, pastel-like colors.
# "bright" – Vibrant, intense colors.
# "pastel" – Lighter shades.
# "dark" – Darker, high-contrast colors.
# "colorblind" – Optimized for colorblind accessibility.

# %% [markdown]
# The bar plot displays the count of each species in the dataset. Based on the visualization:
#
# Equal Distribution:
#
# The three bars (for setosa, versicolor, and virginica) have the same height.
# This suggests that the dataset is balanced, with an equal number of instances (50) for each species.
# Interpretation:
#
# The dataset does not suffer from class imbalance, meaning that all species are equally represented.
# This is important for machine learning models, as imbalanced datasets can lead to biased predictions.

# %%
# Scatter plot for Sepal Length vs Sepal Width
sns.scatterplot(x='sepal_length', y='sepal_width', data=data, hue='species', palette='Set1')
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# sns.scatterplot(...)
#
# Creates a scatter plot using seaborn (sns).
# Plots Sepal Length on the X-axis and Sepal Width on the Y-axis.
# data=data → Uses the data DataFrame (which contains the iris dataset).
# hue='species'
#
# Differentiates points by species (setosa, versicolor, virginica).
# Each species is represented with a different color.
# palette='Set1'
#
# Uses a predefined color scheme (Set1) to enhance visualization.
# plt.title("Scatter Plot: Sepal Length vs Sepal Width")
#
# Adds a title to the scatter plot.
# plt.show()
#
# Displays the plot.

# %% [markdown]
# Distinct Clusters for Each Species
#
# The plot shows three distinct clusters, indicating that different species have unique sepal length and width distributions.
# Setosa (Red) forms a well-separated cluster at the top-left.
# Versicolor (Blue) is in the middle and slightly overlaps with Virginica (Green).
# Virginica (Green) is mostly on the right, with a wider spread.
# Setosa is Clearly Separated
#
# Setosa has relatively higher sepal width and shorter sepal length compared to the other species.
# It is well-separated, suggesting that Sepal Length and Sepal Width alone are sufficient to classify it.
# Overlap Between Versicolor and Virginica
#
# Versicolor and Virginica have overlapping points, meaning Sepal Length and Sepal Width alone may not be enough for perfect classification.
# Other features (like petal length and petal width) might be needed for better separation.
# Trend Observations
#
# Setosa has a wider sepal width compared to the other two species.
# Virginica has a longer sepal length.
# Versicolor lies between the two species in both dimensions.

# %%
# Group by species and calculate mean of each numerical feature
grouped_data = data.groupby('species').mean()
print(grouped_data)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
# Convert 'species' to numerical labels
data['species'] = data['species'].map({'setosa': 0, 'versicolor': 1, 'virginica': 2})

# Or, use one-hot encoding
data = pd.get_dummies(data, drop_first=True)

# %%
# Boxplot with hue for species
sns.boxplot(x='species', y='sepal_length', data=data, palette='muted')
plt.title("Boxplot: Sepal Length by Species")
plt.show()
# Out:
# <ipython-input-15-c7b058dcc9c6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=data, palette='muted')

# %% [markdown]
# Observations from the Boxplot
# The first species (0 - Setosa) has the smallest sepal length, with a compact distribution.
# The second species (1 - Versicolor) has a higher median sepal length than Setosa, with a slightly wider spread.
# The third species (2 - Virginica) has the largest median and widest range, showing a greater variation in sepal length.
# Outliers: A few outliers are present in the Virginica category (below the lower whisker), indicating some exceptionally small sepal lengths.
#
# Sepal length varies significantly across species.
#
# Virginica generally has longer sepals, while Setosa has shorter ones.
#
# There is some overlap between Versicolor and Virginica, but their medians are distinct.

# %%
# Violin plot for Sepal Length by Species
sns.violinplot(x='species', y='sepal_length', data=data, palette='muted')
plt.title("Violin Plot: Sepal Length by Species")
plt.show()
# Out:
# <ipython-input-16-7ff7cd7b6798>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='sepal_length', data=data, palette='muted')

# %% [markdown]
# A violin plot is a combination of a boxplot and a KDE (Kernel Density Estimate) plot, showing both summary statistics and data distribution.
#
# Key Components:
# Shape (Density Curve)
#
# Wider regions indicate higher density (more data points).
# Narrower regions indicate lower density (fewer data points).
# White Dot (Median)
#
# Represents the median (50th percentile) of sepal length for each species.
# Thick Bar (Interquartile Range - IQR)
#
# Contains the middle 50% of the data.
# Whiskers
#
# Extend to the minimum and maximum values within a reasonable range.
